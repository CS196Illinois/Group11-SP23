# %%
#imports modules
import pandas as pd
import string
import geopandas as gpd
from shapely.geometry import Point
from geopy.geocoders import Nominatim
from geopandas.tools import geocode
import time
from random import randint

# %%
#deletes unnamed index as a result of incorrect writing out

df = pd.read_csv("IllinoisNewV2.csv")
del df['Unnamed: 0']

# %%
df = df[df['Address'].isna() == False]
df
# Out:
#                              Name  \
# 0                   Mike's Garage
# 1          Dixon's Seafood Shoppe
# 2                      Asia Grill
# 3                       Paparazzi
# 4                      China Star
# ...                           ...
# 46013  La Gondola Spaghetti House
# 46014                 Village Inn
# 46015        One Restaurant & Bar
# 46016         The Pier Restaurant
# 46017        The Patio Restaurant
#
#                                                 Category priceElement  \
# 0      RestaurantsAutomobile Parts & SuppliesAutomobi...          NaN
# 1      RestaurantsSeafood RestaurantsFish & Seafood M...          NaN
# 2      RestaurantsFamily Style RestaurantsAsian Resta...            $
# 3                         RestaurantsItalian Restaurants           $$
# 4        RestaurantsChinese RestaurantsAsian Restaurants            $
# ...                                                  ...          ...
# 46013                     RestaurantsItalian Restaurants            $
# 46014  RestaurantsAmerican RestaurantsBreakfast, Brun...           $$
# 46015  RestaurantsFamily Style RestaurantsTake Out Re...           $$
# 46016        RestaurantsAmerican RestaurantsSteak Houses          NaN
# 46017                    RestaurantsBarbecue Restaurants          NaN
#
#                     Address                  Locality  ZipCode QueryCategory
# 0            1484 S Main St          Morton, IL 61550    61771    restaurant
# 1            1807 N Main St     East Peoria, IL 61611    61771    restaurant
# 2      5832 N Knoxville Ave          Peoria, IL 61614    61771    restaurant
# 3            4315 N Voss St  Peoria Heights, IL 61616    61771    restaurant
# 4             616 W Raab Rd          Normal, IL 61761    61771    restaurant
# ...                     ...                       ...      ...           ...
# 46013          500 S 8th St          Quincy, IL 62301    62301    restaurant
# 46014         200 N 36th St          Quincy, IL 62301    62301    restaurant
# 46015      600 Hampshire St          Quincy, IL 62301    62301    restaurant
# 46016     401 Bonansinga Dr          Quincy, IL 62301    62301    restaurant
# 46017          133 S 4th St          Quincy, IL 62301    62301    restaurant
#
# [45204 rows x 7 columns]

# %%
#implement trim Category String
#df[df['priceElement'].isna() == False]
#test = df['Category'].iloc[2]


#function to remove String "Restaurants from the column using the replace method"
def removeSubstring(a) -> string:
    return a.replace("Restaurants", "")

# %%
geolocator = Nominatim(user_agent="restaurants")

address = df['Address'] + ", " + df['Locality']
df['NewAddress'] = address
del df['Address']
del df['Locality']
df
#df['geocode'] = df.apply(lambda row: geolocator.geocode(row.Address + " , "+ str(row.ZipCode) + ', IL'), axis=1)
# Out:
#                              Name  \
# 0                   Mike's Garage
# 1          Dixon's Seafood Shoppe
# 2                      Asia Grill
# 3                       Paparazzi
# 4                      China Star
# ...                           ...
# 46013  La Gondola Spaghetti House
# 46014                 Village Inn
# 46015        One Restaurant & Bar
# 46016         The Pier Restaurant
# 46017        The Patio Restaurant
#
#                                                 Category priceElement  \
# 0      RestaurantsAutomobile Parts & SuppliesAutomobi...          NaN
# 1      RestaurantsSeafood RestaurantsFish & Seafood M...          NaN
# 2      RestaurantsFamily Style RestaurantsAsian Resta...            $
# 3                         RestaurantsItalian Restaurants           $$
# 4        RestaurantsChinese RestaurantsAsian Restaurants            $
# ...                                                  ...          ...
# 46013                     RestaurantsItalian Restaurants            $
# 46014  RestaurantsAmerican RestaurantsBreakfast, Brun...           $$
# 46015  RestaurantsFamily Style RestaurantsTake Out Re...           $$
# 46016        RestaurantsAmerican RestaurantsSteak Houses          NaN
# 46017                    RestaurantsBarbecue Restaurants          NaN
#
#        ZipCode QueryCategory                                NewAddress
# 0        61771    restaurant          1484 S Main St, Morton, IL 61550
# 1        61771    restaurant     1807 N Main St, East Peoria, IL 61611
# 2        61771    restaurant    5832 N Knoxville Ave, Peoria, IL 61614
# 3        61771    restaurant  4315 N Voss St, Peoria Heights, IL 61616
# 4        61771    restaurant           616 W Raab Rd, Normal, IL 61761
# ...        ...           ...                                       ...
# 46013    62301    restaurant            500 S 8th St, Quincy, IL 62301
# 46014    62301    restaurant           200 N 36th St, Quincy, IL 62301
# 46015    62301    restaurant        600 Hampshire St, Quincy, IL 62301
# 46016    62301    restaurant       401 Bonansinga Dr, Quincy, IL 62301
# 46017    62301    restaurant            133 S 4th St, Quincy, IL 62301
#
# [45204 rows x 6 columns]

# %%
def getAddress(Address) -> str:
    time.sleep(randint(0,3))
    print(Address)
    try:
        ret = geolocator.geocode(Address)
    except:
        ret = None
    if ret == None:
        Address = Address.split(",")
        Address = str(Address[1::])
        ret = geolocator.geocode(Address)
    return ret
df['Location'] = df.apply(lambda x: getAddress(x.NewAddress), axis = 1)
# Out:
# 1484 S Main St, Morton, IL 61550
# 1807 N Main St, East Peoria, IL 61611
# 5832 N Knoxville Ave, Peoria, IL 61614
# 4315 N Voss St, Peoria Heights, IL 61616
# 616 W Raab Rd, Normal, IL 61761
# 1615 N Main St, Normal, IL 61761
# 939 W Mount Vernon St, Metamora, IL 61548
# 1700 Fredrick Ln, Normal, IL 61761
# 1608 Northbrook Dr, Normal, IL 61761
# 102 W Gridley Rd, Gridley, IL 61744
# 920 N Niles St, Metamora, IL 61548
# 210 W Gridley Rd, Gridley, IL 61744
# 518 E Mount Vernon St, Metamora, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 1311 N Carolyn Dr Ste A, Minonk, IL 61760
# 302 S Eureka St, Goodfield, IL 61742
# 17485 E 2500 North Rd, Hudson, IL 61748
# 25106 N 1750 East Rd, Hudson, IL 61748
# 304 W Washington St, Carlock, IL 61725
# 408 N State St, Roanoke, IL 61561
# 118 W Center St, Eureka, IL 61530
# 408 N State St, Roanoke, IL 61561
# 1902 S Main St, Eureka, IL 61530
# 1101 W Center St, Eureka, IL 61530
# 116 N Main St, Eureka, IL 61530
# 52 N Elm St, El Paso, IL 61738
# 43 W Front St, El Paso, IL 61738
# 609 W Main St, El Paso, IL 61738
# 106 W Bestor St, Secor, IL 61771
# 125 S Main St, Flanagan, IL 61740
# 125 S Main St, Flanagan, IL 61740
# 109 S Main St, Dana, IL 61321
# 102 S 7th St, Wyoming, IL 61491
# 1484 S Main St, Morton, IL 61550
# 1807 N Main St, East Peoria, IL 61611
# 5832 N Knoxville Ave, Peoria, IL 61614
# 4315 N Voss St, Peoria Heights, IL 61616
# 101 N Jefferson St, Washburn, IL 61570
# 102 W Gridley Rd, Gridley, IL 61744
# 52 N Elm St, El Paso, IL 61738
# 210 W Gridley Rd, Gridley, IL 61744
# 43 W Front St, El Paso, IL 61738
# 609 W Main St, El Paso, IL 61738
# 408 N State St, Roanoke, IL 61561
# 302 N Main St, Toluca, IL 61369
# 112 N Main St, Toluca, IL 61369
# 202 N Main St, Toluca, IL 61369
# 408 N State St, Roanoke, IL 61561
# 124 Chestnut St, Wenona, IL 61377
# 570 N Chestnut St, Minonk, IL 61760
# 550 N Chestnut St, Minonk, IL 61760
# 436 N Chestnut St, Minonk, IL 61760
# 1002 N Carolyn Dr, Minonk, IL 61760
# 217 W 1st St, Minonk, IL 61760
# 511 Oak St, Minonk, IL 61760
# 1311 N Carolyn Dr Ste A, Minonk, IL 61760
# 1299 Peoria St, Washington, IL 61571
# 31 E Jackson St Ste B, Morton, IL 61550
# 115 W Saint Paul St, Morton, IL 61550
# 120 N Wilmor Rd, Washington, IL 61571
# 1964 Freedom Pkwy, Washington, IL 61571
# 315 S Main St, Morton, IL 61550
# 313 Muller Rd, Washington, IL 61571
# 1006 Peoria St, Washington, IL 61571
# 1484 S Main St, Morton, IL 61550
# 630 W Jackson St, Morton, IL 61550
# 205 W Jefferson St, Morton, IL 61550
# 837 W Jackson St, Morton, IL 61550
# 2137 Washington Rd, Washington, IL 61571
# 150 E Ashland St, Morton, IL 61550
# 903 W Jackson St, Morton, IL 61550
# 100 S Orchard St, Mackinaw, IL 61755
# 304 W Washington St, Carlock, IL 61725
# 404 N Main St, Washington, IL 61571
# 101 Washington Sq, Washington, IL 61571
# 30525 State Route 9, Mackinaw, IL 61755
# 30573 State Route 9, Mackinaw, IL 61755
# 108 S Main St, Mackinaw, IL 61755
# 118 W Center St, Eureka, IL 61530
# 1902 S Main St, Eureka, IL 61530
# 1101 W Center St, Eureka, IL 61530
# 116 N Main St, Eureka, IL 61530
# 1451 Timberline Rd, Goodfield, IL 61742
# 211 E Peoria St, Goodfield, IL 61742
# 302 S Eureka St, Goodfield, IL 61742
# 304 W Washington St, Carlock, IL 61725
# 116 N Main St, Eureka, IL 61530
# 508 W Cemetery Ave, Chenoa, IL 61726
# 1311 N Carolyn Dr Ste A, Minonk, IL 61760
# 106 Mall Dr, Normal, IL 61761
# 408 N State St, Roanoke, IL 61561
# 408 N State St, Roanoke, IL 61561
# 17485 E 2500 North Rd, Hudson, IL 61748
# 25106 N 1750 East Rd, Hudson, IL 61748
# 102 W Gridley Rd, Gridley, IL 61744
# 210 W Gridley Rd, Gridley, IL 61744
# 23 W Front St, El Paso, IL 61738
# 23 W Front St, El Paso, IL 61738
# 670 W Main St, El Paso, IL 61738
# 660 W Main St, El Paso, IL 61738
# 664 W Main St, El Paso, IL 61738
# 685 W Main St, El Paso, IL 61738
# 101 Delaney Dr, El Paso, IL 61738
# 139 Linco Dr, El Paso, IL 61738
# 139 Linco Dr, El Paso, IL 61738
# 850 W Main St, El Paso, IL 61738
# 197 N Fayette St, El Paso, IL 61738
# 565 W Main St, El Paso, IL 61738
# 133 W Front St, El Paso, IL 61738
# 52 N Elm St, El Paso, IL 61738
# 98 N Cherry St, El Paso, IL 61738
# 52 N Elm St, El Paso, IL 61738
# 43 W Front St, El Paso, IL 61738
# 609 W Main St, El Paso, IL 61738
# 1500 Washington Rd, Washington, IL 61571
# 31 E Jackson St Ste B, Morton, IL 61550
# 115 W Saint Paul St, Morton, IL 61550
# 1311 Washington Rd, Washington, IL 61571
# 1299 Peoria St, Washington, IL 61571
# 120 N Wilmor Rd, Washington, IL 61571
# 408 N State St, Roanoke, IL 61561
# 404 N Main St, Washington, IL 61571
# 101 Washington Sq, Washington, IL 61571
# 315 S Main St, Morton, IL 61550
# 313 Muller Rd, Washington, IL 61571
# 1006 Peoria St, Washington, IL 61571
# 630 W Jackson St, Morton, IL 61550
# 205 W Jefferson St, Morton, IL 61550
# 1304 Cross Creek Dr, Normal, IL 61761
# 120 W North St, Normal, IL 61761
# 43 W Front St, El Paso, IL 61738
# 609 W Main St, El Paso, IL 61738
# 150 E Ashland St, Morton, IL 61550
# 100 S Orchard St, Mackinaw, IL 61755
# 30525 State Route 9, Mackinaw, IL 61755
# 108 S Main St, Mackinaw, IL 61755
# 30573 State Route 9, Mackinaw, IL 61755
# 1101 W Center St, Eureka, IL 61530
# 116 N Main St, Eureka, IL 61530
# 118 W Center St, Eureka, IL 61530
# 1902 S Main St, Eureka, IL 61530
# 304 W Washington St, Carlock, IL 61725
# 302 S Eureka St, Goodfield, IL 61742
# 101 Washington Sq, Washington, IL 61571
# 404 N Main St, Washington, IL 61571
# 1964 Freedom Pkwy, Washington, IL 61571
# 313 Muller Rd, Washington, IL 61571
# 1006 Peoria St, Washington, IL 61571
# 105 Elizabeth Pointe Dr, Germantown Hills, IL 61548
# 385 Old Germantown Rd, Germantown Hills, IL 61548
# 1311 N Carolyn Dr Ste A, Minonk, IL 61760
# 2137 Washington Rd, Washington, IL 61571
# 101 N Jefferson St, Washburn, IL 61570
# 52 N Elm St, El Paso, IL 61738
# 43 W Front St, El Paso, IL 61738
# 609 W Main St, El Paso, IL 61738
# 939 W Mount Vernon St, Metamora, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 1902 S Main St, Eureka, IL 61530
# 1101 W Center St, Eureka, IL 61530
# 518 E Mount Vernon St, Metamora, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 118 W Center St, Eureka, IL 61530
# 116 N Main St, Eureka, IL 61530
# 321 N Main St, Roanoke, IL 61561
# 309 N Main St, Roanoke, IL 61561
# 105 W Husseman St, Roanoke, IL 61561
# 610 W Front St, Roanoke, IL 61561
# 408 N State St, Roanoke, IL 61561
# 116 E Broad St, Roanoke, IL 61561
# 408 N State St, Roanoke, IL 61561
# 408 N State St, Roanoke, IL 61561
# 313 Muller Rd, Washington, IL 61571
# 1006 Peoria St, Washington, IL 61571
# 2137 Washington Rd, Washington, IL 61571
# 4336 E Independence Bouleva, Washington, IL 61571
# 107 E Partridge St, Metamora, IL 61548
# 723 W Mount Vernon St, Metamora, IL 61548
# 801 W Progress St, Metamora, IL 61548
# 417 Jubilee Ln, Germantown Hills, IL 61548
# 901 W Mount Vernon St, Metamora, IL 61548
# 106 W Mount Vernon St, Metamora, IL 61548
# 417 Jubilee Ln, Germantown Hills, IL 61548
# 215 E Mount Vernon St, Metamora, IL 61548
# 126 N Davenport St, Metamora, IL 61548
# 1269 S Woodland Ln, Metamora, IL 61548
# 622 W Mount Vernon St, Metamora, IL 61548
# 400 Woodland Knolls Rd, Germantown Hills, IL 61548
# 232 Whispering Oaks Dr, Germantown Hills, IL 61548
# 128 N Davenport St, Metamora, IL 61548
# 1453 Hickory Point Rd, Metamora, IL 61548
# 939 W Mount Vernon St, Metamora, IL 61548
# 605 Ten Mile Creek Rd, Germantown Hills, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 505 Ten Mile Creek Rd, Germantown Hills, IL 61548
# 521 Jubilee Ln, Germantown Hills, IL 61548
# 385 Old Germantown Rd, Germantown Hills, IL 61548
# 518 E Mount Vernon St, Metamora, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 105 Elizabeth Pointe Dr, Germantown Hills, IL 61548
# 385 Old Germantown Rd, Germantown Hills, IL 61548
# 661 N Cummings Ln, Washington, IL 61571
# 4336 E Independence Bouleva, Washington, IL 61571
# 1500 Washington Rd, Washington, IL 61571
# 1311 Washington Rd, Washington, IL 61571
# 1299 Peoria St, Washington, IL 61571
# 120 N Wilmor Rd, Washington, IL 61571
# 920 N Niles St, Metamora, IL 61548
# 408 N State St, Roanoke, IL 61561
# 404 N Main St, Washington, IL 61571
# 101 Washington Sq, Washington, IL 61571
# 313 Muller Rd, Washington, IL 61571
# 1006 Peoria St, Washington, IL 61571
# 518 E Mount Vernon St, Metamora, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 302 S Eureka St, Goodfield, IL 61742
# 112 S Main St, Eureka, IL 61530
# 744 N Main St, Eureka, IL 61530
# 1464 Us Highway 24, Eureka, IL 61530
# 601 W Center St, Eureka, IL 61530
# 507 W Center St, Eureka, IL 61530
# 118 W Center St, Eureka, IL 61530
# 1980 S Main St, Eureka, IL 61530
# 405 W Center St, Eureka, IL 61530
# 602 N Main St, Eureka, IL 61530
# 112 S Main St, Eureka, IL 61530
# 118 W Center St, Eureka, IL 61530
# 1902 S Main St, Eureka, IL 61530
# 1101 W Center St, Eureka, IL 61530
# 116 N Main St, Eureka, IL 61530
# 511 Oak St, Minonk, IL 61760
# 102 S 7th St, Wyoming, IL 61491
# 1484 S Main St, Morton, IL 61550
# 1807 N Main St, East Peoria, IL 61611
# 5832 N Knoxville Ave, Peoria, IL 61614
# 4315 N Voss St, Peoria Heights, IL 61616
# 939 W Mount Vernon St, Metamora, IL 61548
# 102 W Gridley Rd, Gridley, IL 61744
# 302 N Main St, Toluca, IL 61369
# 112 N Main St, Toluca, IL 61369
# 202 N Main St, Toluca, IL 61369
# 920 N Niles St, Metamora, IL 61548
# 1902 S Main St, Eureka, IL 61530
# 1101 W Center St, Eureka, IL 61530
# 210 W Gridley Rd, Gridley, IL 61744
# 518 E Mount Vernon St, Metamora, IL 61548
# 920 N Niles St, Metamora, IL 61548
# 101 N Jefferson St, Washburn, IL 61570
# 118 W Center St, Eureka, IL 61530
# 116 N Main St, Eureka, IL 61530
# 52 N Elm St, El Paso, IL 61738
# 43 W Front St, El Paso, IL 61738
# 609 W Main St, El Paso, IL 61738
# 408 N State St, Roanoke, IL 61561
# 408 N State St, Roanoke, IL 61561
# 1311 N Carolyn Dr Ste A, Minonk, IL 61760
# 324 Front St, Benson, IL 61516
# 4832 N 2nd St, Loves Park, IL 61111
# 6410 E Riverside Blvd, Loves Park, IL 61111
# 6246 E Riverside Blvd, Loves Park, IL 61111
# 6164 E Riverside Blvd, Loves Park, IL 61111
# 425 Pearl Ave, Loves Park, IL 61111
# 5314 N 2nd St, Loves Park, IL 61111
# 349 E Riverside Blvd, Loves Park, IL 61111
# 6116 N 2nd St, Loves Park, IL 61111
# 200 E Riverside Blvd, Loves Park, IL 61111
# 6338 E Riverside Blvd, Loves Park, IL 61111
# 6430 E Riverside Blvd, Loves Park, IL 61111
# 5529 N 2nd St, Loves Park, IL 61111
# 6075 E Riverside Blvd, Rockford, IL 61114
# 8660 N 2nd St, Machesney Park, IL 61115
# 7834 N 2nd St, Machesney Park, IL 61115
# 7828 N 2nd St, Machesney Park, IL 61115
# 5800 N 2nd St, Loves Park, IL 61111
# 6023 N 2nd St, Loves Park, IL 61111
# 6104 E Riverside Blvd, Loves Park, IL 61111
# 6473 N 2nd St, Loves Park, IL 61111
# 7019 N Alpine Rd, Loves Park, IL 61111
# 1675 E Riverside Blvd, Rockford, IL 61114
# 7784 Forest Hills Rd, Loves Park, IL 61111
# 1824 E Riverside Blvd, Loves Park, IL 61111
# 1718 E Riverside Blvd, Loves Park, IL 61111
# 6590 N Alpine Rd, Loves Park, IL 61111
# 1920 E Riverside Blvd, Loves Park, IL 61111
# 6570 N Alpine Rd, Loves Park, IL 61111
# 7923 N Alpine Rd, Loves Park, IL 61111
# 1726 E. Riverside Drive, Rockford, IL 61111
# 4832 N 2nd St, Loves Park, IL 61111
# 6410 E Riverside Blvd, Loves Park, IL 61111
# 6246 E Riverside Blvd, Loves Park, IL 61111
# 6164 E Riverside Blvd, Loves Park, IL 61111
# 425 Pearl Ave, Loves Park, IL 61111
# 5314 N 2nd St, Loves Park, IL 61111
# 349 E Riverside Blvd, Loves Park, IL 61111
# 6116 N 2nd St, Loves Park, IL 61111
# 200 E Riverside Blvd, Loves Park, IL 61111
# 6338 E Riverside Blvd, Loves Park, IL 61111
# 6430 E Riverside Blvd, Loves Park, IL 61111
# 5529 N 2nd St, Loves Park, IL 61111
# 6075 E Riverside Blvd, Rockford, IL 61114
# 8660 N 2nd St, Machesney Park, IL 61115
# 7834 N 2nd St, Machesney Park, IL 61115
# 7828 N 2nd St, Machesney Park, IL 61115
# 5800 N 2nd St, Loves Park, IL 61111
# 6023 N 2nd St, Loves Park, IL 61111
# 6104 E Riverside Blvd, Loves Park, IL 61111
# 6473 N 2nd St, Loves Park, IL 61111
# 7019 N Alpine Rd, Loves Park, IL 61111
# 1675 E Riverside Blvd, Rockford, IL 61114
# 7784 Forest Hills Rd, Loves Park, IL 61111
# 1824 E Riverside Blvd, Loves Park, IL 61111
# 1718 E Riverside Blvd, Loves Park, IL 61111
# 6590 N Alpine Rd, Loves Park, IL 61111
# 1920 E Riverside Blvd, Loves Park, IL 61111
# 6570 N Alpine Rd, Loves Park, IL 61111
# 7923 N Alpine Rd, Loves Park, IL 61111
# 1726 E. Riverside Drive, Rockford, IL 61111
# 4832 N 2nd St, Loves Park, IL 61111
# 6410 E Riverside Blvd, Loves Park, IL 61111
# 6246 E Riverside Blvd, Loves Park, IL 61111
# 6164 E Riverside Blvd, Loves Park, IL 61111
# 425 Pearl Ave, Loves Park, IL 61111
# 5314 N 2nd St, Loves Park, IL 61111
# 349 E Riverside Blvd, Loves Park, IL 61111
# 6116 N 2nd St, Loves Park, IL 61111
# 200 E Riverside Blvd, Loves Park, IL 61111
# 6338 E Riverside Blvd, Loves Park, IL 61111
# 6430 E Riverside Blvd, Loves Park, IL 61111
# 5529 N 2nd St, Loves Park, IL 61111
# 6075 E Riverside Blvd, Rockford, IL 61114
# 8660 N 2nd St, Machesney Park, IL 61115
# 7834 N 2nd St, Machesney Park, IL 61115
# 7828 N 2nd St, Machesney Park, IL 61115
# 5800 N 2nd St, Loves Park, IL 61111
# 6023 N 2nd St, Loves Park, IL 61111
# 6104 E Riverside Blvd, Loves Park, IL 61111
# 6473 N 2nd St, Loves Park, IL 61111
# 7019 N Alpine Rd, Loves Park, IL 61111
# 1675 E Riverside Blvd, Rockford, IL 61114
# 7784 Forest Hills Rd, Loves Park, IL 61111
# 1824 E Riverside Blvd, Loves Park, IL 61111
# 1718 E Riverside Blvd, Loves Park, IL 61111
# 6590 N Alpine Rd, Loves Park, IL 61111
# 1920 E Riverside Blvd, Loves Park, IL 61111
# 6570 N Alpine Rd, Loves Park, IL 61111
# 7923 N Alpine Rd, Loves Park, IL 61111
# 1726 E. Riverside Drive, Rockford, IL 61111
# 4770 E State St, Rockford, IL 61108
# 7125 Harrison Ave, Rockford, IL 61112
# 2408 S Perryville Rd, Rockford, IL 61108
# 2209 S Perryville Rd, Rockford, IL 61108
# 3905 Broadway, Rockford, IL 61108
# 4410 Charles St, Rockford, IL 61108
# 4414 Charles St, Rockford, IL 61108
# 7200 Harrison Ave, Rockford, IL 61112
# 4228 E State St, Rockford, IL 61108
# 5827 E State St, Rockford, IL 61108
# 4133 Charles St, Rockford, IL 61108
# 4431 E State St, Rockford, IL 61108
# 6007 E State St, Rockford, IL 61108
# 2408 S Perryville Rd, Rockford, IL 61108
# 5555 E State St, Rockford, IL 61108
# 5890 E State St, Rockford, IL 61108
# 5403 E State St, Rockford, IL 61108
# 4358 Sandy Hollow Rd, Rockford, IL 61109
# 4431 E State St, Rockford, IL 61108
# 5611 E State St, Rockford, IL 61108
# 5801 Columbia Pkwy Ste 101, Rockford, IL 61108
# 2526 S Alpine Rd, Rockford, IL 61108
# 5683 Wansford Way, Rockford, IL 61109
# 3206 S Alpine Rd, Rockford, IL 61109
# 4412 Manchester Dr, Rockford, IL 61109
# 4415 Harrison Ave Ste 8, Rockford, IL 61108
# 2560 S Alpine Rd, Rockford, IL 61108
# 4578 Harrison Ave, Rockford, IL 61108
# 4415 Harrison Ave Ste 2, Rockford, IL 61108
# 4415 Harrison Ave, Rockford, IL 61108
# 4770 E State St, Rockford, IL 61108
# 7125 Harrison Ave, Rockford, IL 61112
# 2408 S Perryville Rd, Rockford, IL 61108
# 2209 S Perryville Rd, Rockford, IL 61108
# 3905 Broadway, Rockford, IL 61108
# 4410 Charles St, Rockford, IL 61108
# 4414 Charles St, Rockford, IL 61108
# 7200 Harrison Ave, Rockford, IL 61112
# 4228 E State St, Rockford, IL 61108
# 5827 E State St, Rockford, IL 61108
# 4133 Charles St, Rockford, IL 61108
# 4431 E State St, Rockford, IL 61108
# 6007 E State St, Rockford, IL 61108
# 2408 S Perryville Rd, Rockford, IL 61108
# 5555 E State St, Rockford, IL 61108
# 5890 E State St, Rockford, IL 61108
# 5403 E State St, Rockford, IL 61108
# 4358 Sandy Hollow Rd, Rockford, IL 61109
# 4431 E State St, Rockford, IL 61108
# 5611 E State St, Rockford, IL 61108
# 5801 Columbia Pkwy Ste 101, Rockford, IL 61108
# 2526 S Alpine Rd, Rockford, IL 61108
# 5683 Wansford Way, Rockford, IL 61109
# 3206 S Alpine Rd, Rockford, IL 61109
# 4412 Manchester Dr, Rockford, IL 61109
# 4415 Harrison Ave Ste 8, Rockford, IL 61108
# 2560 S Alpine Rd, Rockford, IL 61108
# 4578 Harrison Ave, Rockford, IL 61108
# 4415 Harrison Ave Ste 2, Rockford, IL 61108
# 4415 Harrison Ave, Rockford, IL 61108
# 1419 W Lane Rd, Machesney Park, IL 61115
# 1419 W Lane Rd Ste D, Machesney Park, IL 61115
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/miniconda3/envs/CS124/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1133 if buffer is not None:
# -> 1134     return self._sslobj.read(len, buffer)
#    1135 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%5B%27+Machesney+Park%27%2C+%27+IL+61115%27%5D&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/geopy/adapters.py:457, in RequestsAdapter._request(self, url, timeout, headers)
#     456 try:
# --> 457     resp = self.session.get(url, timeout=timeout, headers=headers)
#     458 except Exception as error:
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%5B%27+Machesney+Park%27%2C+%27+IL+61115%27%5D&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# Cell In[17], line 13
#      11         ret = geolocator.geocode(Address)
#      12     return ret
# ---> 13 df['Location'] = df.apply(lambda x: getAddress(x.NewAddress), axis = 1)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[17], line 13, in <lambda>(x)
#      11         ret = geolocator.geocode(Address)
#      12     return ret
# ---> 13 df['Location'] = df.apply(lambda x: getAddress(x.NewAddress), axis = 1)
#
# Cell In[17], line 11, in getAddress(Address)
#       9     Address = Address.split(",")
#      10     Address = str(Address[1::])
# ---> 11     ret = geolocator.geocode(Address)
#      12 return ret
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/geopy/geocoders/nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/geopy/adapters.py:447, in RequestsAdapter.get_json(self, url, timeout, headers)
#     446 def get_json(self, url, *, timeout, headers):
# --> 447     resp = self._request(url, timeout=timeout, headers=headers)
#     448     try:
#     449         return resp.json()
#
# File ~/miniconda3/envs/CS124/lib/python3.11/site-packages/geopy/adapters.py:469, in RequestsAdapter._request(self, url, timeout, headers)
#     467         raise GeocoderServiceError(message)
#     468     else:
# --> 469         raise GeocoderUnavailable(message)
#     470 elif isinstance(error, requests.Timeout):
#     471     raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%5B%27+Machesney+Park%27%2C+%27+IL+61115%27%5D&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
#df2 = df[df['Location'].isna() == True]
#df2 = df2[df2['priceElement'].isna() == True]
df2 = df[df['NewAddress'].isna()]
df2
# Out:
#                              Name  \
# 28                 MrBeast Burger
# 33                 MrBeast Burger
# 34                      Pizza Hut
# 52                 MrBeast Burger
# 86                 MrBeast Burger
# ...                           ...
# 45790         Bavaria Sausage Inc
# 45870   Just One More Bar & Grill
# 45874         Bavaria Sausage Inc
# 45901   Just One More Bar & Grill
# 45903         Bavaria Sausage Inc
#
#                                                 Category priceElement  \
# 28     RestaurantsAmerican RestaurantsLatin American ...          NaN
# 33                                           Restaurants          NaN
# 34                  RestaurantsPizzaTake Out Restaurants          NaN
# 52     RestaurantsAmerican RestaurantsLatin American ...          NaN
# 86     RestaurantsAmerican RestaurantsLatin American ...          NaN
# ...                                                  ...          ...
# 45790                    RestaurantsSausagesGift Baskets          NaN
# 45870                        RestaurantsBar & GrillsBars          NaN
# 45874                    RestaurantsSausagesGift Baskets          NaN
# 45901                        RestaurantsBar & GrillsBars          NaN
# 45903                    RestaurantsSausagesGift Baskets          NaN
#
#        ZipCode QueryCategory NewAddress  \
# 28       61771    restaurant        NaN
# 33       61760    restaurant        NaN
# 34       61760    restaurant        NaN
# 52       61760    restaurant        NaN
# 86       61742    restaurant        NaN
# ...        ...           ...        ...
# 45790    62339    restaurant        NaN
# 45870    62324    restaurant        NaN
# 45874    62324    restaurant        NaN
# 45901    62320    restaurant        NaN
# 45903    62320    restaurant        NaN
#
#                                                 Location
# 28                                                  None
# 33     (Nanno, Ville d'Anaunia, Comunità della Val di...
# 34     (Nanno, Ville d'Anaunia, Comunità della Val di...
# 52                                                  None
# 86                                                  None
# ...                                                  ...
# 45790                                               None
# 45870                                               None
# 45874                                               None
# 45901                                               None
# 45903                                               None
#
# [814 rows x 7 columns]
